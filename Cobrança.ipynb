# %% [markdown]
# # Automação de cobranças feita Por Guilherme Silva dia 10/08/2022

# %%
# importando biblioteca pyautogui, controla mouse e teclado:
import pyautogui as pg


#importando biblioteca de tempo time
import time

# %% [markdown]
# # Alguns dos principais funções do python.
#
# pyautogui.write() -> Escrever.
#
# pyautogui.click() -> Clicar com mouse.
#
# pyautogui.locateOnScreen -> identifica uma imagem na sua tela.
#
# pyautogui.hotkey -> usa atalhos do teclado.
#
# pyautogui.press -> aperta um botão do teclado.

# %%
# importando biblioteca pyautogui, controla mouse e teclado:
import pyautogui as pg


#importando biblioteca de tempo time
import time



                                    
                                             
    
          
acrescentar_contato = input("quais contatos quer mandar menssagem ") 
contatos = ["index-0"]


while acrescentar_contato !="n":
    contatos.append(str(acrescentar_contato))
    acrescentar_contato = input("Adicionar mais contato! para encerar digite n ")




    


                
                  
                  
                  
                  
#precionar tecla Win
pg.press("win")

#tempo de 0.5 segundos
time.sleep(0.5)

#escrever chrome
pg.write("opera")

#tempo de 5 segundos
time.sleep(0.5)

#pressionar enter
pg.press("enter")








#tempo de 5 segundos
time.sleep(5)

#escrever link do wpp
pg.write("https://web.whatsapp.com")

#pressionar enter
pg.press("enter")







#tempo de 10 segundos
time.sleep(20)












#LOOP PARA ENVIAR PARA VARIOS CONTATOS

######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisa de contato.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)

#escrever o nome do contato
pg.write(contatos[1])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = "ola tudo bem, vi aqui que voce esta com debitos de, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia." 

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[1])

#tempo de 3 segundos
time.sleep(3)
    


    
    
    

######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[2])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[2])

#tempo de 3 segundos
time.sleep(3)












######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[3])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[3])

#tempo de 3 segundos
time.sleep(3)








######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[4])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[4])

#tempo de 3 segundos
time.sleep(3)










######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[5])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[5])

#tempo de 3 segundos
time.sleep(3)









######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[6])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[6])

#tempo de 3 segundos
time.sleep(3)










######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[7])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[7])

#tempo de 3 segundos
time.sleep(3)










######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[8])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[8])

#tempo de 3 segundos
time.sleep(3)










######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[9])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[9])

#tempo de 3 segundos
time.sleep(3)













######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[10])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[10])

#tempo de 3 segundos
time.sleep(3)








######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[11])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[11])

#tempo de 3 segundos
time.sleep(3)











######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[12])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[12])

#tempo de 3 segundos
time.sleep(3)










######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[13])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[13])

#tempo de 3 segundos
time.sleep(3)










######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[14])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[14])

#tempo de 3 segundos
time.sleep(3)













######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[15])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[15])

#tempo de 3 segundos
time.sleep(3)











######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[16])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[16])

#tempo de 3 segundos
time.sleep(3)














######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[17])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[17])

#tempo de 3 segundos
time.sleep(3)
















######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[18])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[18])

#tempo de 3 segundos
time.sleep(3)












######Localizar imagem barra de pesquisa wpp#######
x, y, largura, altura = pg.locateOnScreen("pesquisar de contato parte 2.png")
#clicar na imagem
pg.click(x + largura / 2, y + altura / 2)

#tempo de 1 segundos
time.sleep(1)
    
#escrever o nome do contato
pg.write(contatos[19])

#tempo de 1 segundos
time.sleep(1)

#clicar na posição do contato
pg.click(x=204, y=347)
 
    
#tempo de 1 segundos
time.sleep(1)

menssagem = f'''ola tudo bem, vi aqui que voce esta com debitos, pedimos a voce que assim que possivel tente realizar o pagamentos. Tenha um excelente dia.'''

#escrever menssagem
pg.write(menssagem)

#tempo de 1 segundos
time.sleep(1)

#pressionar enter
pg.press("enter")

print("menssagem enviada para:", contatos[19])

#tempo de 3 segundos
time.sleep(3)
# Out:
# quais contatos quer mandar menssagem 31 9651-6090
# Adicionar mais contato! para encerar digite n 11 95639-5329
# Adicionar mais contato! para encerar digite n 31 9748-0394
# Adicionar mais contato! para encerar digite n 62 9159-6155
# Adicionar mais contato! para encerar digite n 22 99281-7809
# Adicionar mais contato! para encerar digite n 14 99631-4920
# Adicionar mais contato! para encerar digite n 16 98840-7792
# Adicionar mais contato! para encerar digite n 55 31 9505-3897
# Adicionar mais contato! para encerar digite n 16 99784-0769
# Adicionar mais contato! para encerar digite n 62 9469-6462
# Adicionar mais contato! para encerar digite n n
# menssagem enviada para: 31 9651-6090
# menssagem enviada para: 11 95639-5329
# menssagem enviada para: 31 9748-0394
# menssagem enviada para: 62 9159-6155
# menssagem enviada para: 22 99281-7809
# menssagem enviada para: 14 99631-4920
# menssagem enviada para: 16 98840-7792
# menssagem enviada para: 55 31 9505-3897
# ...

# %%
#tempo de 5 segundos
time.sleep(5)

pg.position()
# Out:
# Point(x=231, y=289)
